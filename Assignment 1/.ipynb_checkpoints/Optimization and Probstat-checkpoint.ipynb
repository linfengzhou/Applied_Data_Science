# %% [markdown]
# # Applied Data Science Assignment 1

# %% [markdown]
# Note: Set Environment for Assignment

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
sns.set(context='notebook', style='whitegrid', palette='deep', 
        font='sans-serif', font_scale=1, rc=None)
from mpl_toolkits.mplot3d import Axes3D
from scipy.optimize import minimize
from numpy import random
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Optimization Homework
# Let $f(x_1,x_2)=x_1^2-x_2^2$
#
# Graph $f(x)$ over a relevant domain using R or Python.  Find all critical points and determine their nature both by hand and by using R or Python.  Submit code and results.

# %% [markdown]
# ### Hand Solution
# <center>$\because$   $f_{x_1}: 2x_1=0$
#    $f_{x_2}: -2x_2=0$ </center>
#
# <center>$\therefore$  (0,0) is a critical point </center>
#
# <center>$\because$    $f_{x_1x_1}=2$  , $f_{x_1x_2}=0$   , $f_{x_2x_2}=-2$
#     $f_{x_1x_1}f_{x_2x_2}-f_{x_1x_2}^2<0$
#     $\therefore$  (0,0) is a saddle point </center>
# <center>$\max_{x} f(x): \lim_{x_1\to \infty ,x_2}f(x_1,x_2)=\infty$  </center>
# <center>$\min_{x} f(x): \lim_{x_1, x_2\to \infty}f(x_1,x_2)=-\infty$  </center>

# %% [markdown]
# ### Python Solution

# %%
## Optimization f(x) = x1 ^2 -x2 ^2
x1 = np.linspace(-10,10,100)
x2 = np.linspace(-10,10,100)
x1, x2 = np.meshgrid(x1, x2)
f = x1**2 - x2**2

# %%
fig = plt.figure(figsize = (12, 10))
ax = Axes3D(fig)
ax.plot_wireframe(x1, x2, f, rstride=4, cstride=4, color='#AD5300')
ax.view_init(20,50)
ax.set_xlabel(r'$x_1$', fontsize = 16)
ax.set_ylabel(r'$x_2$', fontsize = 16)
ax.set_zlabel(r'$f(x_1, x_2)$', fontsize = 16)

# %%
fig = plt.figure(figsize = (12, 10))
ax = Axes3D(fig)
ax.plot_surface(x1, x2, f, rstride=2, cstride=2, cmap=cm.coolwarm, shade='interp')
ax.view_init(20,50)
ax.set_xlabel(r'$x_1$', fontsize = 16)
ax.set_ylabel(r'$x_2$', fontsize = 16)
ax.set_zlabel(r'$f(x_1, x_2)$', fontsize = 16)

# %%
def func(params, sign=1.0):
    x1, x2 = params
    return sign*(x1**2 - x2**2)

minimize(func, [-10.0, 10.0], args=(1.0,), method='BFGS',
         options={'disp': True})
# Out:
# Divide-by-zero encountered: rhok assumed large
# Optimization terminated successfully.
#          Current function value: -5312757422059584.000000
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 27
#    status: 0
#   success: True
#      njev: 27
#      nfev: 108
#  hess_inv: array([[ 10863667.20006022,  10891315.20006023],
#        [ 10864691.20006023,  10893363.20006024]])
#       fun: -5312757422059584.0
#         x: array([  2.78751748e+08,   2.88123748e+08])
#   message: 'Optimization terminated successfully.'
#       jac: array([ 0.,  0.])
#       nit: 3

# %% [markdown]
# ## Probability and Statistics Homework

# %% [markdown]
# ### Question 1
# Suppose you had two 8-sided dice, and your experiment is toss these two dice 25 times. The random variables are the outcomes on each die from each toss. Calculate the mean, standard deviation, and correlation of these two random variables.

# %% [markdown]
# #### Solution

# %%
np.random.seed(seed=11223)

dice_1 = random.random_integers(1,8,25)
dice_2 = random.random_integers(1,8,25)

print "The mean of dices are: ", dice_1.mean(), dice_2.mean()
print "The standard deviation of dices are: ", dice_1.std(),dice_2.std()
print "The correlation of dices is: ", np.corrcoef(dice_1, dice_2)[0, 1]
# Out:
# The mean of dices are:  4.32 4.28
# The standard deviation of dices are:  2.03410914161 2.25424044858
# The correlation of dices is:  0.00662977964302

# %% [markdown]
# ### Question 2-4
# - Generate 1,000 draws from the bivariate normal, setting the correlation coefficient, ρ, it to 0, -0.5, 0.8, and 0.99. Graph the scatter plots, calculate moments, and generate scatterplots. How does the negative correlation affect your results, in particular the scatterplots? How does a high correlation affect your results?
#
# -  Increase the sample size to 10,000 and repeat 2 above.  How does the larger sample affect your results?
#
# -  Return to a sample size of 1,000.  Increase the variances of the random variable $x_1$ to 3 and of the random variable $x_2$ to 5.  Repeat 2 above.  How does the larger variance affect your results?

# %% [markdown]
# #### Define Bivariate Normal Class

# %%
class BivariateNormal:
    def __init__(self, ss, mean, var1, var2, corr):
        """Create a new bivariate normal instance
        
        ss   Sample size of the observed data
        mean Mean zero
        corr Correlation
        """ 
        self._ss = ss
        self._mean = mean
        self._corr = corr
        self._var1 = var1
        self._var2 = var2
    
    def get_bm(self):
        """Return the Bivariate Narmal Distribution"""
        r = np.matrix([[self._var1, self._corr], [self._corr, self._var2]])
        x1, x2 = np.random.multivariate_normal(self._mean, r, self._ss).T
        return x1, x2
        
    def plot_sca(self):
        """Return Scatterplot"""
        x1, x2 = self.get_bm()
        plt.plot(x1, x2, 'bo')
        plt.xlim(-4, 4)
        plt.ylim(-4, 4)
        plt.xlabel(r'$x_1$', fontsize=16)
        plt.ylabel(r'$x_2$', fontsize=16)

    def get_mo(self):
        x1, x2 = self.get_bm()
        print "The distribution mean are:", x1.mean(), x2.mean()
        print "The distribution var are:", x1.var(), x2.var()
        print "The distribution std are:", x1.std(), x2.std()
        print "The distribution corrcoef is:", np.corrcoef(x1, x2)[1, 0]
        

def plot4sca():
    fig = plt.figure(figsize=(12, 10))
    ax1 = fig.add_subplot(2, 2, 1)
    m1.plot_sca()
    plt.title(r'Scatterplot of $\rho$=0', fontsize=20)
    ax2 = fig.add_subplot(2, 2, 2)
    m2.plot_sca()
    plt.title(r'Scatterplot of $\rho$=-0.5', fontsize=20)
    ax3 = fig.add_subplot(2, 2, 3)
    m3.plot_sca()
    plt.title(r'Scatterplot of $\rho$=0.8', fontsize=20)
    ax4 = fig.add_subplot(2, 2, 4)
    m4.plot_sca()
    plt.title(r'Scatterplot of $\rho$=0.99', fontsize=20)

# %% [markdown]
# #### Solution for Question 2

# %%
m1 = BivariateNormal(1000, [0, 0], 1, 1, 0)
m2 = BivariateNormal(1000, [0, 0], 1, 1, -0.5)
m3 = BivariateNormal(1000, [0, 0], 1, 1, 0.8)
m4 = BivariateNormal(1000, [0, 0], 1, 1, 0.99)
plot4sca()

# %%
print "Here are the first distribution moments:"
m1.get_mo()
print "Here are the second distribution moments:"
m2.get_mo()
print "Here are the third distribution moments:"
m3.get_mo()
print "Here are the forth distribution moments:"
m4.get_mo()
# Out:
# Here are the first distribution moments:
# The distribution mean are: 0.0322290597017 -0.0170809040174
# The distribution var are: 1.02311514816 1.05288770003
# The distribution std are: 1.01149154626 1.02610316247
# The distribution corrcoef is: -0.00512284451197
# Here are the second distribution moments:
# The distribution mean are: 0.0349517063022 0.0525839141943
# The distribution var are: 1.01039238082 1.01344214318
# The distribution std are: 1.00518275991 1.00669863573
# The distribution corrcoef is: -0.496841580863
# Here are the third distribution moments:
# The distribution mean are: -0.0439383525341 -0.040762639032
# The distribution var are: 1.00073376692 1.01612094518
# The distribution std are: 1.00036681618 1.00802824622
# The distribution corrcoef is: 0.804357013859
# Here are the forth distribution moments:
# The distribution mean are: -0.00970658220891 -0.011962646508
# The distribution var are: 0.966900789493 0.967029998724
# ...

# %% [markdown]
# #### Comment:
# Q: How does the negative correlation affect your results, in particular the scatterplots? How does a high correlation affect your results?
# A: The negative correlation made second scatterplot show different pattern to others, which means $x_2$ will decrease when $x_1$ increase. A high correlation lets scatterplot become highly central and linear.

# %% [markdown]
# #### Solution for Question 3

# %%
m1 = BivariateNormal(10000, [0, 0], 1, 1, 0)
m2 = BivariateNormal(10000, [0, 0], 1, 1, -0.5)
m3 = BivariateNormal(10000, [0, 0], 1, 1, 0.8)
m4 = BivariateNormal(10000, [0, 0], 1, 1, 0.99)
plot4sca()

# %%
print "Here are the first distribution moments:"
m1.get_mo()
print "Here are the second distribution moments:"
m2.get_mo()
print "Here are the third distribution moments:"
m3.get_mo()
print "Here are the forth distribution moments:"
m4.get_mo()
# Out:
# Here are the first distribution moments:
# The distribution mean are: -0.0159030511087 -0.00239489292503
# The distribution var are: 1.00085711005 0.994133833884
# The distribution std are: 1.00042846323 0.997062602791
# The distribution corrcoef is: -0.0178480004372
# Here are the second distribution moments:
# The distribution mean are: 0.00834023469825 -0.00441045120019
# The distribution var are: 0.984530430679 1.00969059614
# The distribution std are: 0.992235068257 1.00483361615
# The distribution corrcoef is: -0.499254723057
# Here are the third distribution moments:
# The distribution mean are: 0.00880063712261 0.0100833886057
# The distribution var are: 0.992199008556 1.0022179539
# The distribution std are: 0.996091867529 1.00110836271
# The distribution corrcoef is: 0.794274395286
# Here are the forth distribution moments:
# The distribution mean are: -0.0125047788573 -0.0145987667342
# The distribution var are: 1.00032324877 1.0005254183
# ...

# %% [markdown]
# #### Comment:
# Q: Increase the sample size to 10,000 and repeat 2 above.  How does the larger sample affect your results?
# A: There are more points in scatterplot, which make plots more clear. There will be more outliers with decrease of correlation coefficient

# %% [markdown]
# #### Solution for Question 4

# %%
m1 = BivariateNormal(1000, [0, 0], 3, 5, 0)
m2 = BivariateNormal(1000, [0, 0], 3, 5, -0.5)
m3 = BivariateNormal(1000, [0, 0], 3, 5, 0.8)
m4 = BivariateNormal(1000, [0, 0], 3, 5, 0.99)
plot4sca()

# %%
print "Here are the first distribution moments:"
m1.get_mo()
print "Here are the second distribution moments:"
m2.get_mo()
print "Here are the third distribution moments:"
m3.get_mo()
print "Here are the forth distribution moments:"
m4.get_mo()
# Out:
# Here are the first distribution moments:
# The distribution mean are: -0.0594551933181 0.0471197789891
# The distribution var are: 2.86170296345 4.67095880671
# The distribution std are: 1.6916568693 2.16124010853
# The distribution corrcoef is: 0.0036349850218
# Here are the second distribution moments:
# The distribution mean are: 0.0486898990604 -0.0323168893098
# The distribution var are: 3.0038424189 5.07531131204
# The distribution std are: 1.73315966342 2.25284515936
# The distribution corrcoef is: -0.14078034176
# Here are the third distribution moments:
# The distribution mean are: -0.029507623453 -0.00715664158726
# The distribution var are: 2.91736528981 4.92342759793
# The distribution std are: 1.70802965133 2.218879807
# The distribution corrcoef is: 0.239488191019
# Here are the forth distribution moments:
# The distribution mean are: -0.0456947363594 0.0820551676974
# The distribution var are: 2.90106593383 4.94431169872
# ...

# %% [markdown]
# #### Comment:
# Q: Return to a sample size of 1,000.  Increase the variances of the random variable $x_1$ to 3 and of the random variable $x_2$ to 5.  Repeat 2 above.  How does the larger variance affect your results?
# A: The larger variance made data become dispersion. Even correlation coefficient is 0.99, you cannot see any relationship between $x_1$ and $x_2$

# %% [markdown]
# ###Question 5
# Q: Are there any general conclusions that you can draw from this exercise?
# A: This exercise has shown how parameters like correlation coefficient, sample sieze and variance affect Bivariate Normal scatter plot.The larger correlation coefficient or sample size or less variance will make scatter plots more central or linear, vice versa.
